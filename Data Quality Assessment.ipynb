# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
transactions = pd.read_excel(r"C:\Users\SOUBHIK MANDAL\Desktop\Intership\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='Transactions')
new_customer_lists = pd.read_excel(r"C:\Users\SOUBHIK MANDAL\Desktop\Intership\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='NewCustomerList')
customer_demographic = pd.read_excel(r"C:\Users\SOUBHIK MANDAL\Desktop\Intership\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='CustomerDemographic')
customer_add = pd.read_excel(r"C:\Users\SOUBHIK MANDAL\Desktop\Intership\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name='CustomerAddress')

# %% [markdown]
# # Exploring the Transactions Dataset

# %%
transactions
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
transactions = transactions.drop(['Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis = 1)

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
transactions['transaction_date'] = pd.to_datetime(transactions['transaction_date'], unit='s')
transactions['transaction_date'].head()
# Out:
# 0   2017-02-25
# 1   2017-05-21
# 2   2017-10-16
# 3   2017-08-31
# 4   2017-10-01
# Name: transaction_date, dtype: datetime64[ns]

# %%
transactions['product_first_sold_date'] = pd.to_datetime(transactions['product_first_sold_date'], unit='s')
transactions['product_first_sold_date']
# Out:
# 0       1970-01-01 11:27:25
# 1       1970-01-01 11:35:01
# 2       1970-01-01 10:06:01
# 3       1970-01-01 10:02:25
# 4       1970-01-01 11:43:46
#                 ...
# 19995   1970-01-01 10:30:23
# 19996   1970-01-01 09:52:40
# 19997   1970-01-01 11:13:30
# 19998   1970-01-01 10:36:56
# 19999   1970-01-01 10:05:34
# Name: product_first_sold_date, Length: 20000, dtype: datetime64[ns]

# %%
transactions.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  Unnamed: 13  Unnamed: 14  Unnamed: 15
# count   19803.000000          0.0          0.0          0.0
# mean      556.046951          NaN          NaN          NaN
# std       405.955660          NaN          NaN          NaN
# ...

# %% [markdown]
# # Exploring Missing Values

# %%
transactions.isnull().sum()
# Out:
# transaction_id                 0
# product_id                     0
# customer_id                    0
# transaction_date               0
# online_order                 360
# order_status                   0
# brand                        197
# product_line                 197
# product_class                197
# product_size                 197
# list_price                     0
# standard_cost                197
# product_first_sold_date      197
# Unnamed: 13                20000
# Unnamed: 14                20000
# Unnamed: 15                20000
# dtype: int64

# %% [markdown]
# # Identifying Duplicate Values

# %%
dups = transactions.duplicated()
transactions[dups].sum()
# Out:
# transaction_id    0.0
# product_id        0.0
# customer_id       0.0
# online_order      0.0
# order_status      0.0
# brand             0.0
# product_line      0.0
# product_class     0.0
# product_size      0.0
# list_price        0.0
# standard_cost     0.0
# Unnamed: 13       0.0
# Unnamed: 14       0.0
# Unnamed: 15       0.0
# dtype: float64

# %% [markdown]
# # Exploring Columns

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
transactions['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
transactions['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
transactions['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %% [markdown]
# # Exploring New Customer List Dataset

# %%
new_customer_lists
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
new_customer_lists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
cols = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20']
new_customer_lists = new_customer_lists.drop(cols, axis=1)
new_customer_lists.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %% [markdown]
# # Explore Columns

# %%
new_customer_lists['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
new_customer_lists['gender'].str.replace('U','Unspecified')
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: gender, Length: 1000, dtype: object

# %%
new_customer_lists['DOB'].describe()
# Out:
# <ipython-input-22-29c3cca5a8f7>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   new_customer_lists['DOB'].describe()
# count                     983
# unique                    958
# top       1993-11-02 00:00:00
# freq                        2
# first     1938-06-08 00:00:00
# last      2002-02-27 00:00:00
# Name: DOB, dtype: object

# %% [markdown]
# # Exploring Customer Demographic

# %%
customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
customer_demographic['default'].value_counts()
# Out:
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# Ù¡Ù¢Ù£                                     53
#                                          ...
# ð¾ ð ð ð ð ð ð ð                           31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: default, Length: 90, dtype: int64

# %%
customer_demographic = customer_demographic.drop('default', axis=1)
customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
customer_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
customer_demographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %%
customer_demographic['gender'] = customer_demographic['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')
customer_demographic['gender'].value_counts()
# Out:
# Female         2039
# Male           1873
# Unspecified      88
# Name: gender, dtype: int64

# %% [markdown]
# # Merge all customer information from three tables into one table

# %%
new_customer_lists
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
customer_demographic
# Out:
#       customer_id      first_name  last_name       gender  \
# 0               1         Laraine  Medendorp       Female
# 1               2             Eli    Bockman         Male
# 2               3           Arlin     Dearle         Male
# 3               4          Talbot        NaN         Male
# 4               5  Sheila-kathryn     Calton       Female
# ...           ...             ...        ...          ...
# 3995         3996         Rosalia   Halgarth       Female
# 3996         3997          Blanch     Nisuis       Female
# 3997         3998          Sarene    Woolley  Unspecified
# 3998         3999       Patrizius        NaN         Male
# 3999         4000           Kippy    Oldland         Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# ...

# %%
customer_add
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
customer_demographic = pd.merge(customer_demographic, customer_add, how='left', on='customer_id')
customer_demographic
# Out:
#       customer_id      first_name  last_name       gender  \
# 0               1         Laraine  Medendorp       Female
# 1               2             Eli    Bockman         Male
# 2               3           Arlin     Dearle         Male
# 3               4          Talbot        NaN         Male
# 4               5  Sheila-kathryn     Calton       Female
# ...           ...             ...        ...          ...
# 3995         3996         Rosalia   Halgarth       Female
# 3996         3997          Blanch     Nisuis       Female
# 3997         3998          Sarene    Woolley  Unspecified
# 3998         3999       Patrizius        NaN         Male
# 3999         4000           Kippy    Oldland         Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# ...

# %%
new_customer_lists
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
new_df = pd.concat([customer_demographic, new_customer_lists], ignore_index=True, sort=False)
new_df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp  Female
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 4995          NaN       Ferdinand  Romanetti    Male
# 4996          NaN            Burk    Wortley    Male
# 4997          NaN        Melloney      Temby  Female
# 4998          NaN          Dickie    Cubbini    Male
# 4999          NaN           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      33 1961-10-03
# 4                                      56 1977-05-13
# ...

# %%
customer_demographic = new_df
customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp  Female
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 4995          NaN       Ferdinand  Romanetti    Male
# 4996          NaN            Burk    Wortley    Male
# 4997          NaN        Melloney      Temby  Female
# 4998          NaN          Dickie    Cubbini    Male
# 4999          NaN           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      33 1961-10-03
# 4                                      56 1977-05-13
# ...
